# %%
import pandas as pd

# %%
data_dict = pd.read_pickle("pageview_mammal_monthly.pkl")
# Convert dictionary to DataFrame (animal names as index)
data = pd.DataFrame.from_dict(data_dict, orient='index')
data.head()
# Out:
#                                                                      de  \
# Coryphomys musseri    {'timestamp': ['2020110100', '2020120100', '20...
# Rattus rattus         {'timestamp': ['2015070100', '2015080100', '20...
# Lagothrix lagotricha  {'timestamp': ['2015070100', '2015080100', '20...
# Ochotona coreana      {'timestamp': ['2018040100', '2018050100', '20...
# Ochotona gloveri      {'timestamp': ['2016100100', '2016110100', '20...
#
#                                                                      en  \
# Coryphomys musseri    {'timestamp': ['2020090100', '2020100100', '20...
# Rattus rattus         {'timestamp': ['2015070100', '2015080100', '20...
# Lagothrix lagotricha  {'timestamp': ['2021110100', '2021120100', '20...
# Ochotona coreana      {'timestamp': ['2023060100', '2024010100', '20...
# Ochotona gloveri      {'timestamp': ['2015070100', '2015080100', '20...
#
#                                                                      uk  \
# ...
